# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2 as cv

plt.rcParams["figure.figsize"] = (18, 12)

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')
img = cv.imread('images/1.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
i=0
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        plt.imshow(img)
        crop_img = img[y:y+h, x:x+w].copy() 
        cv.imshow("cropped", crop_img) 
        cv.waitKey(0)
       # stringi=str(i) 
        cv.imwrite("A_face"+str(i)+".png",crop_img)    
    
    cv.destroyAllWindows()
    i=i+1 
plt.show()

# %%
img = cv.imread('images/2.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
i=0
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        plt.imshow(img)
        crop_img = img[y:y+h, x:x+w].copy() 
        cv.imshow("cropped", crop_img) 
        cv.waitKey(0)
       # stringi=str(i) 
        cv.imwrite("B_face"+str(i)+".png",crop_img)    
    
    cv.destroyAllWindows()
    i=i+1 
plt.show()

# %%
img = cv.imread('images/2.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
i=0
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    crop_img = img[y:y+h, x:x+w].copy() 
    cv.imshow("cropped", crop_img) 
    cv.waitKey(0)
       # stringi=str(i) 
    cv.imwrite("C_face"+str(i)+".png",crop_img)    
    
    cv.destroyAllWindows()
    i=i+1 
plt.show()

# %%
img = cv.imread('images/3.png')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
i=0
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    crop_img = img[y:y+h, x:x+w].copy() 
    cv.imshow("cropped", crop_img) 
    cv.waitKey(0)
       # stringi=str(i) 
    cv.imwrite("D_face"+str(i)+".png",crop_img)    
    
    cv.destroyAllWindows()
    i=i+1 
plt.show()

# %%
img = cv.imread('images/5.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
i=0
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    crop_img = img[y:y+h, x:x+w].copy() 
    cv.imshow("cropped", crop_img) 
    cv.waitKey(0)
       # stringi=str(i) 
    cv.imwrite("E_face"+str(i)+".png",crop_img)    
    
    cv.destroyAllWindows()
    i=i+1 
plt.show()

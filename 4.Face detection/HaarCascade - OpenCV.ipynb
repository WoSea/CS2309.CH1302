# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')
img = cv.imread('images/1.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img
# Out:
# array([[[ 14,  86,  96],
#         [ 17,  89,  99],
#         [ 17,  89,  99],
#         ...,
#         [ 95, 117, 115],
#         [ 97, 119, 117],
#         [ 99, 121, 119]],
#
#        [[ 17,  92, 101],
#         [ 20,  95, 104],
#         [ 22,  94, 104],
#         ...,
#         [101, 123, 121],
#         [103, 125, 123],
#         [106, 128, 126]],
#
#        [[ 14,  89,  98],
#         [ 17,  92, 101],
#         [ 17,  92, 101],
#         ...,
#         [ 99, 121, 119],
#         [102, 124, 122],
#         [104, 126, 124]],
#
#        ...,
#
#        [[ 12,  47,  61],
#         [ 18,  53,  67],
#         [ 22,  57,  71],
#         ...,
#         [  7,   9,   9],
#         [  7,   9,   9],
#         [  7,   9,   9]],
#
#        [[ 12,  45,  60],
#         [ 20,  53,  68],
#         [ 26,  59,  74],
#         ...,
#         [  7,   9,   9],
#         [  7,   9,   9],
#         [  7,   9,   9]],
#
#        [[ 12,  45,  60],
#         [ 21,  54,  69],
#         [ 28,  61,  76],
# ...

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
from keras.preprocessing.image import load_img
detec_img = img.copy() 
cv.imwrite('detec1.png',detec_img) 
 
filename = 'detec1.png'
# load an image in PIL format
original = load_img(filename, target_size=(224, 224))
print('PIL image size',original.size)
plt.imshow(original)
plt.show()
# Out:
# Using TensorFlow backend.
# PIL image size (224, 224)

# %%
img = cv.imread('images/2.jpg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY) 
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows() 
detec_img = img.copy() 
cv.imwrite('detec2.png',detec_img) 
 
filename = 'detec2.png'
# load an image in PIL format
original = load_img(filename, target_size=(224, 500))
print('PIL image size',original.size)
plt.imshow(original)
plt.show()
# Out:
# PIL image size (500, 224)

# %%
img = cv.imread('images/3.png')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY) 
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows() 
detec_img = img.copy() 
cv.imwrite('detec3.png',detec_img) 
 
filename = 'detec3.png'
# load an image in PIL format
original = load_img(filename, target_size=(224, 500))
print('PIL image size',original.size)
plt.imshow(original)
plt.show()
# Out:
# PIL image size (500, 224)
